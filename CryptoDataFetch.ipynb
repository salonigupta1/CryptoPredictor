# %% [markdown]
# <a href="https://colab.research.google.com/github/salonigupta1/CryptoPredictor/blob/main/CryptoDataFetch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance
# Out:
# ...
#      |████████████████████████████████| 6.3 MB 16.7 MB/s
# ...
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ...

# %%
# !pip install plotly

# %%
# !pip install numpy

# %%
# !pip install pandas

# %%
import numpy as np
import pandas as pandas
import yfinance as yf
import plotly.graph_objs as go

# %%
data = yf.download(tickers='BTC-INR', period = '22h', interval = '15m')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
print(data)
# Out:
#                                  Open        High  ...   Adj Close       Volume
# Datetime                                           ...
# 2021-12-05 18:00:00+00:00  3711833.25  3711833.25  ...  3710619.00            0
# 2021-12-05 18:15:00+00:00  3710618.00  3714599.75  ...  3701707.00   1276903424
# 2021-12-05 18:30:00+00:00  3702601.75  3715328.75  ...  3715328.75   7397703680
# 2021-12-05 18:45:00+00:00  3711633.25  3714444.25  ...  3699517.50            0
# 2021-12-05 19:00:00+00:00  3700104.25  3701585.00  ...  3678622.25            0
# ...                               ...         ...  ...         ...          ...
# 2021-12-06 14:15:00+00:00  3653998.00  3655724.25  ...  3648570.00   5188878336
# 2021-12-06 14:30:00+00:00  3650979.00  3660964.25  ...  3630151.00  11605377024
# 2021-12-06 14:45:00+00:00  3636904.75  3639585.00  ...  3629035.00  14785970176
# 2021-12-06 15:00:00+00:00  3632417.00  3636228.50  ...  3635073.75   1660944384
# ...

# %%
data.to_csv('dataset.csv')

# %%
import pandas as pd
datasetFromCSV = pd.read_csv('/content/dataset.csv')
print(datasetFromCSV)
# Out:
#                      Datetime        Open  ...   Adj Close       Volume
# 0   2021-12-05 18:00:00+00:00  3711833.25  ...  3710619.00            0
# 1   2021-12-05 18:15:00+00:00  3710618.00  ...  3701707.00   1276903424
# 2   2021-12-05 18:30:00+00:00  3702601.75  ...  3715328.75   7397703680
# 3   2021-12-05 18:45:00+00:00  3711633.25  ...  3699517.50            0
# 4   2021-12-05 19:00:00+00:00  3700104.25  ...  3678622.25            0
# ..                        ...         ...  ...         ...          ...
# 81  2021-12-06 14:15:00+00:00  3653998.00  ...  3648570.00   5188878336
# 82  2021-12-06 14:30:00+00:00  3650979.00  ...  3630151.00  11605377024
# 83  2021-12-06 14:45:00+00:00  3636904.75  ...  3629035.00  14785970176
# 84  2021-12-06 15:00:00+00:00  3632417.00  ...  3635073.75   1660944384
# 85  2021-12-06 15:05:46+00:00  3634119.50  ...  3634119.50            0
#
# [86 rows x 7 columns]

# %%
fig = go.Figure()

# %%
fig.add_trace(go.Candlestick(x=data.index,
                open=data['Open'],
                high=data['High'],
                low=data['Low'],
                close=data['Close'], name = 'market data'))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2c236459-ae1e-4714-bd22-b98a5cba10f7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2c236459-ae1e-4714-bd22-b98a5cba10f7")) {
#                     Plotly.newPlot(
#                         '2c236459-ae1e-4714-bd22-b98a5cba10f7',
# ...

# %%
fig.update_layout(
    title='Bitcoin live share price evolution',
    yaxis_title='Bitcoin Price (kUS Dollars)')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="11f4676f-656b-4f3d-bfd7-d7f779adb438" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("11f4676f-656b-4f3d-bfd7-d7f779adb438")) {
#                     Plotly.newPlot(
#                         '11f4676f-656b-4f3d-bfd7-d7f779adb438',
# ...

# %%
fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=15, label="15m", step="minute", stepmode="backward"),
            dict(count=45, label="45m", step="minute", stepmode="backward"),
            dict(count=1, label="HTD", step="hour", stepmode="todate"),
            dict(count=6, label="6h", step="hour", stepmode="backward"),
            dict(step="all")
        ])
    )
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="499611ba-3608-41ab-a30d-d5227ed9cec4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("499611ba-3608-41ab-a30d-d5227ed9cec4")) {
#                     Plotly.newPlot(
#                         '499611ba-3608-41ab-a30d-d5227ed9cec4',
# ...

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2e17e068-5907-4637-a563-e03a476c19f7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2e17e068-5907-4637-a563-e03a476c19f7")) {
#                     Plotly.newPlot(
#                         '2e17e068-5907-4637-a563-e03a476c19f7',
# ...
